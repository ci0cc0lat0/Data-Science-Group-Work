# %%
import pandas as pd
import numpy as np
import os
import glob
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn
import sklearn
from shapely.geometry import Point, Polygon
import scipy

seaborn.set()
# numpy pandas shapely geopandas rasterio
cwd_path = os.getcwd()
usa_quake_path = cwd_path + "\\earthquake_contiguous_usa_12batch\\"
eu_quake_path = cwd_path + "\\Earthquake_2016_2018_all_eu\\"

# %%
# Used to enumerate the files in each directory.
# Useful for finding a sepcific file's index for the us_df[] and eu_df[] arrays/list

for x, us in enumerate(glob.glob(usa_quake_path+"*.csv")):
    print("%2i %s" % (x,os.path.basename(us)))
print()
for x, eu in enumerate(glob.glob(eu_quake_path+"*.csv")):
    print("%2i %s" % (x,os.path.basename(eu)))
# Out:
#  0 Earthquake_2020_09_2020_10_filtered.csv
#  1 Earthquake_2020_11_2020_12_filtered.csv
#  2 Earthquake_2021_01_2021_02_filtered.csv
#  3 Earthquake_2021_03_2021_04_filtered.csv
#  4 Earthquake_2021_05_2021_06_filtered.csv
#  5 Earthquake_2021_07_2021_08_filtered.csv
#  6 Earthquake_2021_09_2021_10_filtered.csv
#  7 Earthquake_2021_11_2021_12_filtered.csv
#  8 Earthquake_2022_01_2022_02_filtered.csv
#  9 Earthquake_2022_03_2022_04_filtered.csv
# 10 Earthquake_2022_05_2022_06_filtered.csv
# 11 Earthquake_2022_07_2022_08_filtered.csv
#
#  0 Earthquake_2016_10_filtered_eu.csv
#  1 Earthquake_2016_11_filtered_eu.csv
#  2 Earthquake_2016_12_filtered_eu.csv
#  3 Earthquake_2016_1_filtered_eu.csv
#  4 Earthquake_2016_2_filtered_eu.csv
#  5 Earthquake_2016_3_filtered_eu.csv
#  6 Earthquake_2016_4_filtered_eu.csv
#  7 Earthquake_2016_5_filtered_eu.csv
#  8 Earthquake_2016_6_filtered_eu.csv
#  9 Earthquake_2016_7_filtered_eu.csv
# 10 Earthquake_2016_8_filtered_eu.csv
# 11 Earthquake_2016_9_filtered_eu.csv
# 12 Earthquake_2017_10_filtered_eu.csv
# 13 Earthquake_2017_11_filtered_eu.csv
# 14 Earthquake_2017_12_filtered_eu.csv
# 15 Earthquake_2017_1_filtered_eu.csv
# 16 Earthquake_2017_2_filtered_eu.csv
# 17 Earthquake_2017_3_filtered_eu.csv
# 18 Earthquake_2017_4_filtered_eu.csv
# 19 Earthquake_2017_5_filtered_eu.csv
# 20 Earthquake_2017_6_filtered_eu.csv
# 21 Earthquake_2017_7_filtered_eu.csv
# 22 Earthquake_2017_8_filtered_eu.csv
# 23 Earthquake_2017_9_filtered_eu.csv
# 24 Earthquake_2018_10_filtered_eu.csv
# 25 Earthquake_2018_11_filtered_eu.csv
# 26 Earthquake_2018_12_filtered_eu.csv
# 27 Earthquake_2018_1_filtered_eu.csv
# 28 Earthquake_2018_2_filtered_eu.csv
# 29 Earthquake_2018_3_filtered_eu.csv
# 30 Earthquake_2018_4_filtered_eu.csv
# 31 Earthquake_2018_5_filtered_eu.csv
# 32 Earthquake_2018_6_filtered_eu.csv
# 33 Earthquake_2018_7_filtered_eu.csv
# 34 Earthquake_2018_8_filtered_eu.csv
# 35 Earthquake_2018_9_filtered_eu.csv

# %%
# CSVs are appended to an array/list as DataFames.
# Done for both US and EU data
us_df = []
eu_df = []
for us in glob.glob(usa_quake_path+"*.csv"):
    us_df.append(pd.read_csv(us))


for eu in glob.glob(eu_quake_path+"*.csv"):
    eu_df.append(pd.read_csv(eu))

# %%
# Batch allocation
us_batch = []
for y in range(10):
    batch = pd.concat((us_df[y+0], us_df[y+1], us_df[y+2]),ignore_index=True)
    us_batch.append(batch)
print(len(us_batch))
print(us_batch)
# Out:
# 10
# [                          time   latitude   longitude      depth   mag
# 0     2020-09-01T00:30:52.227Z  38.176500 -117.801900   6.700000  3.50
# 1     2020-09-01T00:36:59.811Z  38.003900 -118.235800   6.600000  3.40
# 2     2020-09-01T01:39:34.960Z  36.394333 -120.437000   9.190000  2.87
# 3     2020-09-01T02:25:49.130Z  42.370000 -118.444000   8.450000  3.52
# 4     2020-09-01T05:51:36.757Z  38.179800 -117.863400   9.200000  3.30
# ...                        ...        ...         ...        ...   ...
# 1649  2021-02-28T20:12:49.320Z  34.326167 -116.923500   5.510000  2.94
# 1650  2021-02-28T20:56:22.890Z  32.068176 -102.241449   8.779256  3.20
# 1651  2021-02-28T21:38:38.590Z  36.363167  -98.155333   7.220000  3.68
# 1652  2021-02-28T22:00:42.397Z  31.688448 -104.300805   6.568604  3.20
# 1653  2021-02-28T23:32:57.854Z  38.169400 -117.898600  11.600000  2.80
#
# [1654 rows x 5 columns],                           time   latitude   longitude      depth   mag
# 0     2020-11-01T00:47:37.474Z  31.606700 -104.248600   5.000000  3.00
# 1     2020-11-01T01:50:56.968Z  31.629500 -104.475300   5.000000  2.80
# 2     2020-11-01T02:28:21.810Z  34.512667  -86.615667  13.070000  2.62
# 3     2020-11-01T04:15:45.029Z  31.722900 -104.087000   5.000000  2.80
# 4     2020-11-01T08:33:38.671Z  46.872200 -112.511800  11.390000  2.50
# ...                        ...        ...         ...        ...   ...
# 1479  2021-04-30T10:15:30.983Z  32.117615 -102.138553   7.018514  3.20
# 1480  2021-04-30T13:20:01.576Z  44.343800 -115.228700  10.000000  2.60
# 1481  2021-04-30T14:59:35.170Z  38.811333 -122.797167   3.670000  2.76
# 1482  2021-04-30T17:21:18.789Z  47.615700  -92.593000   0.000000  3.20
# 1483  2021-04-30T21:35:43.520Z  34.044667 -117.045500  11.480000  2.64
#
# [1484 rows x 5 columns],                           time   latitude   longitude      depth   mag
# 0     2021-01-01T01:23:24.836Z  32.301900 -101.798200   5.000000  3.10
# 1     2021-01-01T01:31:14.910Z  35.034667  -97.832500   9.420000  2.76
# 2     2021-01-01T02:27:17.518Z  34.879500 -110.779700   5.000000  2.70
# 3     2021-01-01T04:49:35.388Z  32.285400 -101.808700   5.000000  2.60
# 4     2021-01-01T05:26:06.861Z  44.080800 -114.981200   3.000000  3.90
# ...                        ...        ...         ...        ...   ...
# 1432  2021-06-30T22:15:56.120Z  35.779167 -117.587000   6.710000  3.23
# 1433  2021-06-30T22:19:19.600Z  39.135333 -122.221500  -0.270000  3.17
# 1434  2021-06-30T22:36:25.188Z  31.658261 -104.315367   6.542896  3.10
# 1435  2021-06-30T22:42:53.581Z  45.840600 -106.690100   0.000000  3.00
# 1436  2021-06-30T23:13:53.413Z  40.493700 -116.056400  12.200000  3.40
#
# [1437 rows x 5 columns],                           time   latitude   longitude      depth   mag
geo_us_batch = []
for y in range(10):
    geo_us_batch.append(gpd.GeoDataFrame(us_batch[y]))

# %%
plt.rcParams["figure.figsize"] = [20, 20]
states = gpd.read_file('data/usa-states-census-2014.shp')
states.plot()
plt.scatter(geo_us_batch[0].longitude, geo_us_batch[0].latitude,c="red",marker='.')

# %%
# Geo pandas stuff
d = us_batch[0][:]
geo = gpd.GeoDataFrame(d.drop(['longitude', 'latitude'], axis = 1), crs='epsg:4326',geometry=[Point(xy) for xy in zip(d.longitude, d.latitude)])

fig, ax = plt.subplots(figsize=(20,20))
ax.set_aspect('equal')

geo_states = gpd.read_file('data/usa-states-census-2014.shp')
geo_states.plot(ax=ax)
geo.plot(ax=ax, alpha=0.5, cmap='viridis', linewidth=0.8,marker='o')
geo
# Out:
#                           time      depth   mag                     geometry
# 0     2020-09-01T00:30:52.227Z   6.700000  3.50  POINT (-117.80190 38.17650)
# 1     2020-09-01T00:36:59.811Z   6.600000  3.40  POINT (-118.23580 38.00390)
# 2     2020-09-01T01:39:34.960Z   9.190000  2.87  POINT (-120.43700 36.39433)
# 3     2020-09-01T02:25:49.130Z   8.450000  3.52  POINT (-118.44400 42.37000)
# 4     2020-09-01T05:51:36.757Z   9.200000  3.30  POINT (-117.86340 38.17980)
# ...                        ...        ...   ...                          ...
# 1649  2021-02-28T20:12:49.320Z   5.510000  2.94  POINT (-116.92350 34.32617)
# 1650  2021-02-28T20:56:22.890Z   8.779256  3.20  POINT (-102.24145 32.06818)
# 1651  2021-02-28T21:38:38.590Z   7.220000  3.68   POINT (-98.15533 36.36317)
# 1652  2021-02-28T22:00:42.397Z   6.568604  3.20  POINT (-104.30081 31.68845)
# 1653  2021-02-28T23:32:57.854Z  11.600000  2.80  POINT (-117.89860 38.16940)
#
# [1654 rows x 4 columns]

# %%
extent = x_min, x_max, y_min, y_max = [d.longitude.min(), d.longitude.max(), d.latitude.min(), d.latitude.max()]
grid_x, grid_y = np.mgrid[x_min:x_max:2, y_min:y_max:1]
# Out:
# [<matplotlib.lines.Line2D at 0x15fa4141610>,
#  <matplotlib.lines.Line2D at 0x15fa4141580>,
#  <matplotlib.lines.Line2D at 0x15fa4141280>,
#  <matplotlib.lines.Line2D at 0x15fa41414f0>,
#  <matplotlib.lines.Line2D at 0x15fa2722310>,
#  <matplotlib.lines.Line2D at 0x15fa2722130>,
#  <matplotlib.lines.Line2D at 0x15fa2722040>,
#  <matplotlib.lines.Line2D at 0x15fa2722ac0>,
#  <matplotlib.lines.Line2D at 0x15fa2722d60>,
#  <matplotlib.lines.Line2D at 0x15fa27227c0>,
#  <matplotlib.lines.Line2D at 0x15fa41416d0>,
#  <matplotlib.lines.Line2D at 0x15fa2722220>,
#  <matplotlib.lines.Line2D at 0x15fa2722700>,
#  <matplotlib.lines.Line2D at 0x15fa2722760>,
#  <matplotlib.lines.Line2D at 0x15fa2722c10>,
#  <matplotlib.lines.Line2D at 0x15fa553a820>,
#  <matplotlib.lines.Line2D at 0x15fa274cbb0>,
#  <matplotlib.lines.Line2D at 0x15fa274c670>,
#  <matplotlib.lines.Line2D at 0x15fa274c6d0>,
#  <matplotlib.lines.Line2D at 0x15fa274c9a0>,
#  <matplotlib.lines.Line2D at 0x15fa274cd30>]
